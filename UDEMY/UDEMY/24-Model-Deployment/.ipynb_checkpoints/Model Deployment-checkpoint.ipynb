# %%
import pandas as pd

# %%
df = pd.read_csv("../DATA/Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 4)

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
X = df.drop("sales", axis=1) 
y = df["sales"]

# %%
from sklearn.model_selection import train_test_split
#TRAIN / Validation / Hold out test
# 70%  /  15%  / 15% ==100

# 1st split - 70/30
# 2nd split 50/50

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
X_train.shape
# Out:
# (140, 3)

# %%
X_validation, X_holdout_test, y_validation, y_holdout_test = train_test_split(X_test, y_test, test_size=0.50, random_state=101)

# %%
len(X)
# Out:
# 200

# %%
len(X_validation)
# Out:
# 30

# %%
X_test.shape
# Out:
# (60, 3)

# %%
y_test.shape
# Out:
# (60,)

# %%
len(X)
# Out:
# 200

# %% [markdown]
# # Model Training

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=3, random_state=101)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=3, random_state=101)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
validation_predictions = model.predict(X_validation)

# %%
validation_predictions
# Out:
# array([14.43333333,  6.46666667,  5.1       , 15.16666667, 11.4       ,
#         9.96666667, 11.63333333, 12.1       , 19.        ,  7.03333333,
#        12.43333333, 21.9       , 13.13333333,  7.2       , 11.7       ,
#         7.56666667, 14.26666667, 12.6       , 11.16666667,  7.9       ,
#        12.93333333, 21.2       , 19.66666667, 15.76666667, 15.9       ,
#        25.06666667, 20.4       ,  9.83333333, 14.56666667, 19.66666667])

# %%
validation_predictions.shape
# Out:
# (30,)

# %%
mean_absolute_error(y_validation, validation_predictions)
# Out:
# 0.853333333333333

# %%
mean_squared_error(y_validation, validation_predictions)**0.5
# Out:
# 1.1031268688998959

# %%
df.describe()["sales"]
# Out:
# count    200.000000
# mean      14.022500
# std        5.217457
# min        1.600000
# 25%       10.375000
# 50%       12.900000
# 75%       17.400000
# max       27.000000
# Name: sales, dtype: float64

# %%
model = RandomForestRegressor(n_estimators=30, random_state=101)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=30, random_state=101)

# %%
validation_predictions = model.predict(X_validation)

# %%
validation_predictions
# Out:
# array([14.40333333,  5.47333333,  4.14      , 15.72666667, 11.66666667,
#         9.93      , 10.83333333, 11.48      , 18.02      ,  7.60333333,
#        10.9       , 21.44333333, 14.08333333,  7.53333333, 11.81333333,
#         6.83      , 13.51      , 13.62      , 11.01333333,  7.99666667,
#        12.53333333, 21.63      , 19.49      , 15.73      , 16.05666667,
#        24.21666667, 20.17666667,  9.50666667, 14.50333333, 19.36333333])

# %%
mean_absolute_error(y_validation, validation_predictions)
# Out:
# 0.6575555555555552

# %%
mean_squared_error(y_validation, validation_predictions)**0.5
# Out:
# 0.8542009478215644

# %% [markdown]
# ## Final performance metrics (HOLDOUT SET)

# %%
holdout_preditions = model.predict(X_holdout_test)

# %%
mean_absolute_error(y_holdout_test, holdout_preditions)
# Out:
# 0.5937777777777775

# %%
mean_squared_error(y_holdout_test, holdout_preditions)**0.5
# Out:
# 0.745323693040418

# %%
final_model = RandomForestRegressor(n_estimators=30, random_state=101)

# %%
final_model.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=30, random_state=101)

# %%
import joblib

# %%
joblib.dump(final_model, "final_model_Rishat.pkl")
# Out:
# ['final_model_Rishat.pkl']

# %%
X.columns
# Out:
# Index(['TV', 'radio', 'newspaper'], dtype='object')

# %%
list(X.columns)
# Out:
# ['TV', 'radio', 'newspaper']

# %%
joblib.dump(list(X.columns), "col_names_Rishat.pkl")
# Out:
# ['col_names_Rishat.pkl']

# %% [markdown]
# ## Loading Model

# %%
new_columns = joblib.load("col_names_Rishat.pkl")

# %%
new_columns
# Out:
# ['TV', 'radio', 'newspaper']

# %%
loaded_model = joblib.load("final_model_Rishat.pkl")

# %%
loaded_model
# Out:
# RandomForestRegressor(n_estimators=30, random_state=101)

# %%
loaded_model.predict([[230.1, 37.8, 69.2]])
# Out:
# C:\Users\rd\.conda\envs\tensorflow\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([21.99])

# %% [markdown]
# # Model Deployment API
# ## Part2: Creating API Script
